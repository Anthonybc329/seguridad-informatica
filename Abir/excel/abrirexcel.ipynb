# %%
import openpyxl

libro_excel = openpyxl.load_workbook("ejemplo.xlsx")
hoja = libro_excel.active

# Accede a las celdas en la hoja de cálculo
for fila in hoja.iter_rows():
    for celda in fila:
        print(celda.value)
# Out:
# CATEGORÍA
# MARCA
# REFERENCIA
# NOMBRE
# COLOR
# DAMA O CABALLERO
# MOVIMIENTO
# RESERVA DE MARCHA
# DIÁMETRO
# RESISTENCIA AL AGUA
# ESFERA
# MATERIAL DE CAJA
# CASE
# MATERIAL BRAZALETE
# STRAP MATERIAL
# FUNCIONALIDADES
# MAIN FEATURES
# DESCRIPCIÓN
# (50 palabras max)
# DESCRIPCIÓN EN INGLES (50 palabras max)
# Garantía
# Imagen de referncia
# RELOJERÍA
# PANERAI
# PAM01084
# Luminor Logo
# negro
# cabellero
# Movimiento mecánico de cuerda manual, calibre P.6000
# Reserva de marcha de tres días, un barrilete. 110 componentes
# 44mm
# 100 m
# Negra con números arábigos e índices horarios luminiscentes. Segundero pequeño a las 9 horas.
#
#
# acero pulido AISI 316L
# AISI 316L polished steel
# Piel de becerro Ponte Vecchio negro, pespuntes beige, STD, 24/22, BA
# Black Ponte Vecchio calfskin, beige stitching, STD, 24/22, BA
# Minutos, Segundero pequeño, horas
# Minutes, small seconds, hours
# Movimiento mecánico de cuerda manual, calibre P.6000, 15½ líneas, 4,5 mm de espesor, 19 rubíes, 21.600 alternancias/hora. Dispositivo antichoque Incabloc®. Reserva de marcha de tres días, un barrilete. 110 componentes
# Mechanical hand-wound movement, caliber P.6000, 15½ lines, 4.5 mm thick, 19 jewels, 21,600 vibrations/hour. Incabloc® anti-shock device. Three-day power reserve, one barrel. 110 components
# 2 años
# None
# RELOJERÍA
# PANERAI
# PAM02661
# Luminor Marina CarboTech™
# negro
# cabellero
# Mecánico automático, calibre P.9010, íntegramente realizado por Panerai
#  Reserva de marcha de 3 días, dos barriletes. 200 componentes.
# 44mm
# 300m
# Negra con números arábigos e índices horarios luminiscentes
# Carbotech™
# Carbotech™
# Tejido PET reciclado pespuntes azul claro, STD, 24/22, BA
# Recycled PET fabric light blue stitching, STD, 24/22, BA
# Horas, minutos, segundero pequeño, fecha
# Hours, minutes, small seconds, date
# Mecánico automático, calibre P.9010, íntegramente realizado por Panerai, 13 ¾ líneas, 6,0 mm de espesor, 31 rubíes, volante Glucydur®, 28.800 alternancias/hora. Dispositivo antichoque Incabloc®.
# Automatic mechanical, caliber P.9010, entirely made by Panerai, 13 ¾ lines, 6.0 mm thick, 31 jewels, Glucydur® balance, 28,800 vibrations/hour. Incabloc® anti-shock device.
# 2 años
# None
# RELOJERÍA
# PANERAI
# PAM01361
# Luminor Bitempo
# azul
# cabellero
# Movimiento mecánico automático, calibre P.9012
# Reserva de marcha de 3 días, dos barriletes, puesta a cero del segundero. 231 componentes
# 44mm
# 300m
# Azul con acabado satinado soleil y números arábigos e índices horarios luminiscentes.
#  acero satinado AISI 316L
#
# AISI 316L satin steel
# Piel de aligátor azul oscuro, T/T, 24/22, BA, STD
# Dark blue alligator skin, T/T, 24/22, BA, STD
# Apertura de calendario, Minutos, horas, Reset seconds, Segundero pequeño, GMT12H, Reserva de marcha, Huso horario, dispositivo de parada de segundos
# Calendar aperture, Minutes, hours, Reset seconds, Small seconds, GMT12H, Power reserve, Time zone, stop seconds device
# Movimiento mecánico automático, calibre P.9012, 13¾ líneas, 6,0 mm de espesor, 31 rubíes, volante Glucydur®, 28 800 alternancias/hora. Dispositivo antichoque Incabloc®.
# Automatic mechanical movement, caliber P.9012, 13¾ lines, 6.0 mm thick, 31 jewels, Glucydur® balance, 28,800 vibrations/hour. Incabloc® anti-shock device.
# 2 años
# None
# RELOJERÍA
# PANERAI
# PAM01218
# Luminor Chrono
# negro
# cabellero
# Mecánico automático, calibre P.9200
# Reserva de marcha de 42 horas, un barrilete.
# 44mm
# 100m
# Esfera blanca con números arábigos e índices horarios luminiscentes. Contador de minutos del cronógrafo vaciado a las 3 horas y contador pequeño de segundos a las 9 horas. Segunderos del cronógrafo en el centro. Escala taquimétrica en el realce externo
#  acero satinado AISI 316L
#
# AISI 316L satin steel
# Cocodrilo Negro, Tono sobre tono Pespuntes, 24.0/22.0 Tamaño Estándar
# Black Crocodile, Tone on Tone Stitching, 24.0/22.0 Standard Size
# Minutos, Cronógrafo, Segundero pequeño, horas
# Minutes, Chronograph, Small seconds, hours
# Mecánico automático, calibre P.9200, íntegramente realizado por Panerai, 13 ¼ líneas, 6,9 mm de espesor, 41 rubíes, volante Glucydur®, 28 800 alternancias/hora. Dispositivo antichoque Incabloc®. Reserva de marcha de 42 horas, un barrilete.
# Automatic mechanical, caliber P.9200, entirely made by Panerai, 13 ¼ lines, 6.9 mm thick, 41 jewels, Glucydur® balance, 28,800 vibrations/hour. Incabloc® anti-shock device. 42-hour power reserve, one barrel.
# 2 años
# None
# RELOJERÍA
# PANERAI
# PAM01110
# Luminor Chrono
# azul
# cabellero
# Mecánico automático, calibre P.9201
# Reserva de marcha de 42 horas, un barrilete.
# 44mm
# 100m
# Esfera azul con acabado satinado soleil, números arábigos e índices horarios luminiscentes. Contador de minutos del cronógrafo ahuecado a las 3 horas y segundero pequeño a las 9 horas. Contador de segundos del cronógrafo en el centro. Escala taquimétrica en el realce exterior
#  acero satinado AISI 316L
#
# AISI 316L satin steel
# Acero Pespuntes
# Steel Stitching
# Minutos, Cronógrafo, Segundero pequeño, horas
# Minutes, Chronograph, Small seconds, hours
# Mecánico automático, calibre P.9200, íntegramente realizado por Panerai, 13 ¼ líneas, 6,9 mm de espesor, 41 rubíes, volante Glucydur®, 28 800 alternancias/hora. Dispositivo antichoque Incabloc®. Reserva de marcha de 42 horas, un barrilete.
# Automatic mechanical, caliber P.9200, entirely made by Panerai, 13 ¼ lines, 6.9 mm thick, 41 jewels, Glucydur® balance, 28,800 vibrations/hour. Incabloc® anti-shock device. 42-hour power reserve, one barrel.
# 2 años
# None
# RELOJERÍA
# PANERAI
# PAM01180
# Luminor Due Luna
# rosa
# None
# Movimiento mecánico automático, calibre P.900/MP
#  Reserva de marcha de 3 días, un barrilete. 171 componentes
# 38mm
# 30m
# Azul con acabado satinado soleil y números arábigos e índices horarios luminiscentes. Fecha a las 3 horas y segundero pequeño a las 9 horas.
# acero pulido
# polished steel
# Piel de aligátor azul brillante, azul, STD, 20/18, BA, PAM Click Release System™
# Bright Blue Alligator Skin, Blue, STD, 20/18, BA, PAM Click Release System™
# horas, Minutos, Segundero pequeño, Fase lunar
# hours, minutes, small seconds, moon phase
# Movimiento mecánico automático, calibre P.900/MP, 12½ líneas, 4,2 mm de espesor, 23 rubíes, 28 800 alternancias/hora. Dispositivo antichoque Incabloc®. Reserva de marcha de 3 días, un barrilete. 171 componentes
# Automatic mechanical movement, caliber P.900/MP, 12½ lines, 4.2 mm thick, 23 jewels, 28,800 vibrations/hour. Incabloc® anti-shock device. 3-day power reserve, one barrel. 171 components
# 2 años
# None
# RELOJERÍA
# PANERAI
# PAM01388
# Luminor Due
# negro
# None
# Movimiento mecánico automático, calibre P.900
#  Reserva de marcha de 3 días, un barrilete. 171 componentes
# 42mm
# 50m
# Blanca con acabado satinado soleil y números arábigos e índices horarios luminiscentes. Fecha a las 3 horas y segundero pequeño a las 9 horas
# acero pulido
# polished steel
# Piel de aligátor negra, negra, STD, 22/18, BA, PAM Click Release System™
# Black Alligator Skin, Black, STD, 22/18, BA, PAM Click Release System™
# Apertura de calendario, horas, Minutos, Segundero pequeño
# Calendar aperture, hours, minutes, small seconds
# Movimiento mecánico automático, calibre P.900, 12½ líneas, 4,2 mm de espesor, 23 rubíes, 28.800 alternancias/hora. Dispositivo antichoque Incabloc®. Reserva de marcha de 3 días, un barrilete. 171 componentes
# Automatic mechanical movement, caliber P.900, 12½ lines, 4.2 mm thick, 23 jewels, 28,800 vibrations/hour. Incabloc® anti-shock device. 3-day power reserve, one barrel. 171 components
# 2 años
# None
# RELOJERÍA
# PANERAI
# PAM02683
# Submersible
# negro
# None
# Mecánico automático, calibre P900,
# Reserva de marcha de 3 días, un barrilete. 171 componentes
# 42mm
# 300m
# Fondo atornillado de acero, esfera negra con índices horarios y puntos luminiscentes. Fecha a las 3 horas y segundero pequeño a las 9 horas
#  acero satinado AISI 316L
#
# AISI 316L satin steel
# Caucho Negro, - Pespuntes, 22.0/20.0 Tamaño Estándar
# Black Rubber, - Stitching, 22.0/20.0 Standard Size
# horas, Segundero pequeño, Apertura de calendario, Minutos
# hours, small seconds, calendar aperture, minutes
# Mecánico automático, calibre P900, 12½ líneas, 4,2 mm de espesor, 23 rubíes, 28.800 alternancias/hora. Dispositivo antichoque Incabloc®. Reserva de marcha de 3 días, un barrilete. 171 componentes
# Automatic mechanical, caliber P900, 12½ lines, 4.2 mm thick, 23 jewels, 28,800 vibrations/hour. Incabloc® anti-shock device. 3-day power reserve, one barrel. 171 components
# 2 años
# None
# RELOJERÍA
# PANERAI
# PAM01229
# Submersible QuarantaQuattro
# negro
# None
# Mecánico automático, calibre P900,
# Reserva de marcha de 3 días, un barrilete. 171 componentes
# 44mm
# 300m
# Fondo atornillado y titanio con recubrimiento negro, esfera blanca con marcadores de hora y puntos luminosos.
# AISI 316L acero cepillado
# AISI 316L brushed steel
# Caucho Negro
# Black Rubber
# horas, Segundero pequeño, Apertura de calendario, Minutos
# hours, small seconds, calendar aperture, minutes
# Mecánico automático, calibre P.900, 12½ líneas, 4,2 mm de espesor, 23 rubíes, 28 800 alternancias/hora. Dispositivo antichoque Incabloc®.
# Automatic mechanical, caliber P.900, 12½ lines, 4.2 mm thick, 23 jewels, 28,800 vibrations/hour. Incabloc® anti-shock device.
# 2 años
# None
# RELOJERÍA
# PANERAI
# PAM02070
# Submersible QuarantaQuattro GoldTech ™ OroCarbo
# negro
# None
# Movimiento mecánico de cuerda manual, calibre P.5000, íntegramente realizado por Panerai
# Reserva de marcha de 8 días, dos barriletes. 146 componentes.
# 45mm
# 100m
# Azul degradado con números arábigos e índices horarios luminiscentes.
#  Goldtech™ satinado
#  Goldtech™ satinado
# Caucho negro,
# Black Rubber
# Minutos, Segundero pequeño, horas, Apertura de calendario
# Minutes, Small seconds, hours, Calendar aperture
# Movimiento mecánico de cuerda manual, calibre P.5000, íntegramente realizado por Panerai, 15½ líneas, 4,5 mm de espesor, 21 rubíes, volante Glucydur®, 21.600 alternancias/hora. Dispositivo antichoque Incabloc Parechoc®
# Mechanical hand-wound movement, caliber P.5000, entirely made by Panerai, 15½ lines, 4.5 mm thick, 21 jewels, Glucydur® balance, 21,600 vibrations/hour. Incabloc Parechoc® anti-shock device
# 2 años
# None
# RELOJERÍA
# PANERAI
# PAM02979
# Submersible Marina Militare CarboTech ™
# negro
# None
# Movimiento mecánico automático, calibre P.900/MP
# Reserva de marcha de 3 días, un barrilete. 171 componentes
# 47mm
# 300m
# negra
# Carbotech™
# Carbotech™
# Caucho negro,
# Black Rubber
# Minutos, dispositivo de parada de segundos, Apertura de calendario, Segundero pequeño, horas
# Minutes, stop seconds device, Calendar aperture, Small seconds, hours
# Movimiento mecánico automático, calibre P.9010, íntegramente realizado por Panerai, 13¾ líneas, 6,0 mm de espesor, 31 rubíes, volante Glucydur®, 28.800 alternancias/hora. Dispositivo antichoque Incabloc®. Reserva de marcha de 3 días, dos barriletes. 200 componentes
# Automatic mechanical movement, caliber P.9010, entirely made by Panerai, 13¾ lines, 6.0 mm thick, 31 jewels, Glucydur® balance, 28,800 vibrations/hour. Incabloc® anti-shock device. 3-day power reserve, two barrels. 200 components
# 2 años
# None
# RELOJERÍA
# PANERAI
# PAM02068
# Submersible Blu Notte
# azul
# None
# Movimiento mecánico automático, calibre P.900/MP
# Reserva de marcha de 8 días, dos barriletes.
# 42mm
# 300m
# Azul con acabado satinado soleil y números arábigos e índices horarios luminiscentes.
# acero
# AISI 316L brushed steel
# acero
# AISI 316L brushed steel
# Minutos, dispositivo de parada de segundos, Apertura de calendario, Segundero pequeño, horas
# Minutes, stop seconds device, Calendar aperture, Small seconds, hours
# Movimiento mecánico de cuerda manual, calibre P.5000, creado por Panerai, 15½ líneas, 4,5 mm de espesor, 21 rubíes, volante Glucydur®, 21 600 alternancias/hora. Dispositivo antichoque KIF Parechoc®
# Mechanical hand-wound movement, caliber P.5000, created by Panerai, 15½ lines, 4.5 mm thick, 21 jewels, Glucydur® balance, 21,600 vibrations/hour. KIF Parechoc® anti-shock device
# 2 años
# None
